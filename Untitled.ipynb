# %%
# go to a website
# seearch for a respective product
# locate review part
# scrap all the dat in local system

# %%
# import required library
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS, cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as  uReq

# %%
url = "https://www.flipkart.com/search?q="+"iphone12"

# %%
url
# Out:
# 'https://www.flipkart.com/search?q=iphone12'

# %%
uclient = uReq(url)

# %%
uclient

# %%
page = uclient.read()

# %%
page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.d4bb4f.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
uclient.close()

# %%
page_html = bs(page,"html.parser")

# %%
page_html
# Out:
# <!DOCTYPE html>
# ...

# %%
page = page_html.find_all("div",{"class":"_1AtVbE col-12-12"})

# %%
# here we wre getting total 30 iphone list 
len(page)
# Out:
# 30

# %%
box = page[5]

# %%
box
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBFWBYZTK33MBG9" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-12-white-64-gb/p/itm8b88bdc03cd79?pid=MOBFWBYZTK33MBG9&amp;lid=LSTMOBFWBYZTK33MBG9ZFJ0HL&amp;marketplace=FLIPKART&amp;q=iphone12&amp;store=tyy%2F4io&amp;srno=s_1_3&amp;otracker=search&amp;fm=organic&amp;iid=c0b4d7a8-77bb-4d8d-9185-4995c7a2b24b.MOBFWBYZTK33MBG9.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=nez0yv6r3k0000001693066096374&amp;qH=ad588135f239b88b" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone 12 (White, 64 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/kg8avm80/mobile/j/f/9/apple-iphone-12-dummyapplefsn-original-imafwg8dkyh2zgrh.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30V
# ...

# %%
p_link = "https://www.flipkart.com"+box.div.div.div.a["href"]

# %%
p_req = requests.get(p_link)

# %%
p_req
# Out:
# <Response [200]>

# %%
p_req.encoding = "utf - 8"

# %%
prod_html = bs(p_req.text,"html.parser")

# %%
prod_html
# Out:
# <!DOCTYPE html>
# ...

# %%
# lets extract name  

comment_box[0].find_all("p",{"class":"_2sc7ZR _2V5EHH"})
# Out:
# [<p class="_2sc7ZR _2V5EHH">Sunita  Yadav</p>]

# %%
# make loop to extract 
for i in range(len(comment_box)-1):
    print(comment_box[i].find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
    print(comment_box[i].div.div.div.div.text)
    print(comment_box[i].div.div.div.p.text)
    comtag = comment_box[i].div.div.find_all("div",{"class":""})
    print(comtag[0].div.text)
# Out:
# Sunita  Yadav
# 5
# Classy product
# This is the value for money phone. For Flipkart:On time delieveryAlways best serviceFeedback call received after 5 daysApple:One word: SuperbPicture Quality Ultimate
# Hariprasad b
# 5
# Wonderful
# Performance is soooo fastEspecially faceid detection is awesome even in darkNo need to carry an dslr .this is more than enough attaching puc taken by this
# Rupesh Thik
# 5
# Simply awesome
# Awesome Camera
# Sibsankar Das
# 5
# Must buy!
# Camera quality is just fabulous. Interface is very smooth.  Good for photography and videography.
# Arjun  Chakravarti
# 5
# Classy product
# Awesome
# Sivaramaraju Raju
# 5
# Must buy!
# Best iPhone till date 💕
# Jaya chandra  Reddy
# 5
# Simply awesome
# Amazing phone  In love with this phone
# Manoj Kumar
# 5
# Worth every penny
# Super
# Shivam Kengale
# 5
# Must buy!
# Go for it
# Ankur Sharma
# 4
# Very Good
# display is good , processor is awesome

# %%
# take comments

# %%
comment_box = prod_html.find_all("div",{"class":"_16PBlm"})

# %%
comment_box[0].div.div.div.div.text
# Out:
# '5'

# %%
# take comments 
comment_box[0].div.div.div.p.text
# Out:
# 'Classy product'

# %%
# comtag

comment_box[i].div.div.find_all("div",{"class":""})
# Out:
# [<div><div class="">display is good , processor is awesome</div><span class="_1H-bmy"><span>READ MORE</span></span></div>,
#  <div class="">display is good , processor is awesome</div>,
#  <div></div>]
